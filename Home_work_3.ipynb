# %%
list = [2, 5, 8, 9, 10, 52, 41, 20]
adunare = 0
for element in list:
    adunare+=element
print(adunare)
# Out:
# 147

# %%
#cream lista si variala (adunare) pentru a calcula suma elementelor
list=[]
adunare = 0

#introducem numarul de elemente
print("!!! Important numarul de elemente (n) sa fie (1<=n<=100) !!!")
n = int(input("Introduceti numarul de elemente: "))

#verificam numarul de elemente sa fie mai mare ca 1 si mai mic ca 100
if n >=1 and n<=100:
    print("Introduceti elementele ")

#cream ciclu pentru a introduce elementele conform numarul de elemente create mai sus n    
    for i in range (0, n):
        element = int(input())
        list.append(element)

#printam elemente        
    print(list)

#cream ciclu pentru a insuma elemente    
    for element in list:
        adunare+=element
    print(adunare)

#cream else pentru a finisa programul si a arata ca numarul de elemente este mai mare decit 100    
else :
    print("!!! Numarul de elemente este mai mare decit 100 !!!")
# Out:
# !!! Important numarul de elemente (n) sa fie (1<=n<=100) !!!
# Introduceti numarul de elemente:  2
# Introduceti elementele
#  1
#  2
# [1, 2]
# 3

# %%
list = [2, 5, 8, 9, 10, 52, 41, 20]
produs = 1
for element in list:
    produs*=element
print(produs)
# Out:
# 307008000

# %%
#cream lista si variala (produs) pentru a calcula suma elementelor
list=[]
produs = 1

#introducem numarul de elemente
print("!!! Important numarul de elemente (n) sa fie (1<=n<=100) !!!")
n = int(input("Introduceti numarul de elemente: "))

#verificam numarul de elemente sa fie mai mare ca 1 si mai mic ca 100
if n >=1 and n<=100:
    print("Introduceti elementele ")

#cream ciclu pentru a introduce elementele conform numarul de elemente create mai sus n    
    for i in range (0, n):
        element = int(input())
        list.append(element)

#printam elemente        
    print(list)

#cream ciclu pentru a insuma elemente    
    for element in list:
        produs*=element
    print(produs)

#cream else pentru a finisa programul si a arata ca numarul de elemente este mai mare decit 100    
else :
    print("!!! Numarul de elemente este mai mare decit 100 !!!")
# Out:
# !!! Important numarul de elemente (n) sa fie (1<=n<=100) !!!
# Introduceti numarul de elemente:  3
# Introduceti elementele
#  2
#  2
#  4
# [2, 2, 4]
# 16
